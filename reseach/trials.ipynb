# %%
import os
import gdown

# %%
# %pwd
# Out:
# 'c:\\Users\\2021ICTS28\\Desktop\\Waste_detection_using_YOLOv5\\reseach'

# %%
os.chdir("../")

# %%
url = "https://drive.google.com/file/d/1jpHx6eqofemA9adh4mjXmAzM4hTCQIWi/view?usp=sharing"

# %%
file_id = url.split('/')[-2]
file_id
# Out:
# '1jpHx6eqofemA9adh4mjXmAzM4hTCQIWi'

# %%
prefix = 'https://drive.google.com/uc?/export=download&id='
gdown.download(prefix+file_id, "data/waste_data.zip")
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?/export=download&id=1jpHx6eqofemA9adh4mjXmAzM4hTCQIWi
# From (redirected): https://drive.google.com/uc?%2Fexport=download&id=1jpHx6eqofemA9adh4mjXmAzM4hTCQIWi&confirm=t&uuid=d63cb909-e8c2-4bad-8f23-433cc0c56a18
# To: c:\Users\2021ICTS28\Desktop\Waste_detection_using_YOLOv5\data\waste_data.zip
# 100%|██████████| 40.2M/40.2M [00:03<00:00, 12.6MB/s]
# 'data/waste_data.zip'

# %%
# Out:
# 'c:\\Users\\2021ICTS28\\Desktop\\Waste_detection_using_YOLOv5'
